# %% [markdown]
# <a href="https://colab.research.google.com/github/farid-hamid/FinalYearProjectFH/blob/main/BERTopic_Model_%2B_Classifiers_v7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.feature_extraction.text import CountVectorizer
from matplotlib import pyplot as plt
import seaborn as sns
import re

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import string

# %%
import nltk

# %%
# %pip install umap-learn
# Out:
# Collecting umap-learn
#   Downloading umap-learn-0.5.5.tar.gz (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.9/90.9 kB 3.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.2.2)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (0.58.1)
# Collecting pynndescent>=0.5 (from umap-learn)
#   Downloading pynndescent-0.5.11-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from umap-learn) (4.66.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn) (0.41.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pynndescent>=0.5->umap-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->umap-learn) (3.2.0)
# Building wheels for collected packages: umap-learn
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.5-py3-none-any.whl size=86832 sha256=0c12b781d41b0c77d4f6b5199b06312b75be7b8ba23303fbe37f99eb71f3982f
#   Stored in directory: /root/.cache/pip/wheels/3a/70/07/428d2b58660a1a3b431db59b806a10da736612ebbc66c1bcc5
# Successfully built umap-learn
# Installing collected packages: pynndescent, umap-learn
# Successfully installed pynndescent-0.5.11 umap-learn-0.5.5

# %%
# %pip install HDBSCAN
# Out:
# Collecting HDBSCAN
#   Downloading hdbscan-0.8.33.tar.gz (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 14.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting cython<3,>=0.27 (from HDBSCAN)
#   Using cached Cython-0.29.37-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from HDBSCAN) (1.23.5)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from HDBSCAN) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.20 in /usr/local/lib/python3.10/dist-packages (from HDBSCAN) (1.2.2)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from HDBSCAN) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20->HDBSCAN) (3.2.0)
# Building wheels for collected packages: HDBSCAN
#   Building wheel for HDBSCAN (pyproject.toml) ... done
#   Created wheel for HDBSCAN: filename=hdbscan-0.8.33-cp310-cp310-linux_x86_64.whl size=3039296 sha256=d382af9d2e0e68e8d8cc1b486d26c25af61293a868dfa22c9f5ab15f20af3fda
#   Stored in directory: /root/.cache/pip/wheels/75/0b/3b/dc4f60b7cc455efaefb62883a7483e76f09d06ca81cf87d610
# Successfully built HDBSCAN
# Installing collected packages: cython, HDBSCAN
#   Attempting uninstall: cython
#     Found existing installation: Cython 3.0.8
#     Uninstalling Cython-3.0.8:
#       Successfully uninstalled Cython-3.0.8
# Successfully installed HDBSCAN-0.8.33 cython-0.29.37

# %%
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Unlabelled Discussion DATA.xlsx')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   subReddit            1200 non-null   object
#  1   Date                 1200 non-null   object
#  2   Datetime             1200 non-null   datetime64[ns]
#  3   Title                1194 non-null   object
#  4   Body Text            929 non-null    object
#  5   Top Comment          91 non-null     object
#  6   Top Comment Reply 1  25 non-null     object
#  7   Top Comment Reply 2  10 non-null     object
#  8   Top Comment Reply 3  0 non-null      float64
#  9   Top Comment Reply 4  0 non-null      float64
# dtypes: datetime64[ns](1), float64(2), object(7)
# memory usage: 93.9+ KB

# %%
df.drop_duplicates()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   subReddit            1200 non-null   object
#  1   Date                 1200 non-null   object
#  2   Datetime             1200 non-null   datetime64[ns]
#  3   Title                1194 non-null   object
#  4   Body Text            929 non-null    object
#  5   Top Comment          91 non-null     object
#  6   Top Comment Reply 1  25 non-null     object
#  7   Top Comment Reply 2  10 non-null     object
#  8   Top Comment Reply 3  0 non-null      float64
#  9   Top Comment Reply 4  0 non-null      float64
# dtypes: datetime64[ns](1), float64(2), object(7)
# memory usage: 93.9+ KB

# %%
data = df

# %%
data.head()
# Out:
#      subReddit                 Date            Datetime  \
# 0  diabetes_t2  2023-12-05 00:00:00 2023-12-05 23:25:00
# 1  diabetes_t2  2023-12-20 00:00:00 2023-12-20 05:13:00
# 2  diabetes_t2  2023-12-23 00:00:00 2023-12-23 23:16:00
# 3  diabetes_t2  2023-12-23 00:00:00 2023-12-23 02:32:00
# 4  diabetes_t2  2023-12-07 00:00:00 2023-12-07 16:34:00
#
#                                           Title  \
# 0  Cheapest way to get a CGM without insurance?
# 1                         Libre 3 doesn’t stick
# 2                       Frustrated with Libre 3
# 3                     Libre 3 Graphs 3 weeks in
# 4                    Confused by GMI on Libre 3
#
#                                            Body Text Top Comment  \
# 0  Well after being told my insurance would cover...         NaN
# 1  I’ve used the Libre 3 for 3 months off and on....         NaN
# 2  I just got off the phone with customer support...         NaN
# 3  The first graph was my first full day with my ...         NaN
# 4  I'm finding myself confused by the GMI measure...         NaN
#
#   Top Comment Reply 1 Top Comment Reply 2  Top Comment Reply 3  \
# 0                 NaN                 NaN                  NaN
# 1                 NaN                 NaN                  NaN
# 2                 NaN                 NaN                  NaN
# 3                 NaN                 NaN                  NaN
# 4                 NaN                 NaN                  NaN
#
#    Top Comment Reply 4
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN

# %%
n = len(data)

# %%
data.drop(['Date', 'Datetime'], axis=1)
# Out:
#         subReddit                                              Title  \
# 0     diabetes_t2       Cheapest way to get a CGM without insurance?
# 1     diabetes_t2                              Libre 3 doesn’t stick
# 2     diabetes_t2                            Frustrated with Libre 3
# 3     diabetes_t2                          Libre 3 Graphs 3 weeks in
# 4     diabetes_t2                         Confused by GMI on Libre 3
# ...           ...                                                ...
# 1195  diabetes_t2                                     Morning Spikes
# 1196  diabetes_t2  This is what severe anxiety does to my blood s...
# 1197     diabetes  I tried having it on my arm just once as sugge...
# 1198     diabetes              Mine keeps breaking, on my right arm.
# 1199     diabetes  I just learned you can buy some supplemental c...
#
#                                               Body Text Top Comment  \
# 0     Well after being told my insurance would cover...         NaN
# 1     I’ve used the Libre 3 for 3 months off and on....         NaN
# 2     I just got off the phone with customer support...         NaN
# 3     The first graph was my first full day with my ...         NaN
# 4     I'm finding myself confused by the GMI measure...         NaN
# ...                                                 ...         ...
# 1195  Anyone else get 60/70 point increases in the m...         NaN
# 1196   I did not eat any carbs with either of those ...         NaN
# 1197  The filament bent like 15 minutes after I've p...         NaN
# 1198               I have had 3 break and stop reading.         NaN
# 1199                                                NaN         NaN
#
#      Top Comment Reply 1 Top Comment Reply 2  Top Comment Reply 3  \
# 0                    NaN                 NaN                  NaN
# 1                    NaN                 NaN                  NaN
# 2                    NaN                 NaN                  NaN
# 3                    NaN                 NaN                  NaN
# 4                    NaN                 NaN                  NaN
# ...                  ...                 ...                  ...
# 1195                 NaN                 NaN                  NaN
# 1196                 NaN                 NaN                  NaN
# 1197                 NaN                 NaN                  NaN
# 1198                 NaN                 NaN                  NaN
# 1199                 NaN                 NaN                  NaN
#
#       Top Comment Reply 4
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 1195                  NaN
# 1196                  NaN
# 1197                  NaN
# 1198                  NaN
# 1199                  NaN
#
# [1200 rows x 8 columns]

# %%
#stage 1 lowercase
data['Title'] = data['Title'].str.lower()
data['Body Text'] = data['Body Text'].str.lower()
data['Top Comment'] = data['Top Comment'].str.lower()
data['Top Comment Reply 1'] = data['Top Comment Reply 1'].str.lower()
data['Top Comment Reply 2'] = data['Top Comment Reply 2'].str.lower()
#data['Top Comment Reply 3'] = data['Top Comment Reply 3'].str.lower()
#data['Top Comment Reply 4'] = data['Top Comment Reply 4'].str.lower()

# %%
data.head()
# Out:
#      subReddit                 Date            Datetime  \
# 0  diabetes_t2  2023-12-05 00:00:00 2023-12-05 23:25:00
# 1  diabetes_t2  2023-12-20 00:00:00 2023-12-20 05:13:00
# 2  diabetes_t2  2023-12-23 00:00:00 2023-12-23 23:16:00
# 3  diabetes_t2  2023-12-23 00:00:00 2023-12-23 02:32:00
# 4  diabetes_t2  2023-12-07 00:00:00 2023-12-07 16:34:00
#
#                                           Title  \
# 0  cheapest way to get a cgm without insurance?
# 1                         libre 3 doesn’t stick
# 2                       frustrated with libre 3
# 3                     libre 3 graphs 3 weeks in
# 4                    confused by gmi on libre 3
#
#                                            Body Text Top Comment  \
# 0  well after being told my insurance would cover...         NaN
# 1  i’ve used the libre 3 for 3 months off and on....         NaN
# 2  i just got off the phone with customer support...         NaN
# 3  the first graph was my first full day with my ...         NaN
# 4  i'm finding myself confused by the gmi measure...         NaN
#
#   Top Comment Reply 1 Top Comment Reply 2  Top Comment Reply 3  \
# 0                 NaN                 NaN                  NaN
# 1                 NaN                 NaN                  NaN
# 2                 NaN                 NaN                  NaN
# 3                 NaN                 NaN                  NaN
# 4                 NaN                 NaN                  NaN
#
#    Top Comment Reply 4
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN

# %%
data.fillna('', inplace=True)
data['Discussion'] = data.apply(lambda row: ' '.join(row[['Title', 'Body Text', 'Top Comment']].values), axis=1)

# %%
data.head()
# Out:
#      subReddit                 Date            Datetime  \
# 0  diabetes_t2  2023-12-05 00:00:00 2023-12-05 23:25:00
# 1  diabetes_t2  2023-12-20 00:00:00 2023-12-20 05:13:00
# 2  diabetes_t2  2023-12-23 00:00:00 2023-12-23 23:16:00
# 3  diabetes_t2  2023-12-23 00:00:00 2023-12-23 02:32:00
# 4  diabetes_t2  2023-12-07 00:00:00 2023-12-07 16:34:00
#
#                                           Title  \
# 0  cheapest way to get a cgm without insurance?
# 1                         libre 3 doesn’t stick
# 2                       frustrated with libre 3
# 3                     libre 3 graphs 3 weeks in
# 4                    confused by gmi on libre 3
#
#                                            Body Text Top Comment  \
# 0  well after being told my insurance would cover...
# 1  i’ve used the libre 3 for 3 months off and on....
# 2  i just got off the phone with customer support...
# 3  the first graph was my first full day with my ...
# 4  i'm finding myself confused by the gmi measure...
#
#   Top Comment Reply 1 Top Comment Reply 2 Top Comment Reply 3  \
# 0
# 1
# 2
# 3
# 4
#
#   Top Comment Reply 4                                         Discussion
# 0                      cheapest way to get a cgm without insurance? w...
# 1                      libre 3 doesn’t stick i’ve used the libre 3 fo...
# 2                      frustrated with libre 3 i just got off the pho...
# 3                      libre 3 graphs 3 weeks in the first graph was ...
# 4                      confused by gmi on libre 3 i'm finding myself ...

# %%
def remove_punctuation_and_emojis(text):
    if not isinstance(text, str):
        #if text is not a string, return it as it is
        return text

    punctuation = string.punctuation
    #punctuation translator
    translator = str.maketrans('', '', string.punctuation)
    #remove punctuation
    text = text.translate(translator)

    #regex pattern for emojis
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F700-\U0001F77F"  # alchemical symbols
                           u"\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
                           u"\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
                           u"\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
                           u"\U0001FA00-\U0001FA6F"  # Chess Symbols
                           u"\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
                           u"\U00002702-\U000027B0"  # Dingbats
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    text = emoji_pattern.sub(r'', text) #removals

    return text

# %%
data['Discussion'] = data['Discussion'].apply(lambda x: remove_punctuation_and_emojis(x))

# %%
#stage 5: removal of numbers and other incoherent chars
def remove_chars(text):

    if isinstance(text, str):
        #replace numbers with empty string, remove nd,rd,st, http and www, any strings longer than 26 chars
        text = re.sub(r'\d+', '', text)
        text = re.sub(r'\bnd\b|\b[a-zA-Z]{1,2}\b', '', text)
        text = re.sub(r'\brd\b|\b[a-zA-Z]{1,2}\b', '', text)
        text = re.sub(r'\bst\b|\b[a-zA-Z]{1,2}\b', '', text)
        text = re.sub(r'\bblah\b|\b[a-zA-Z]{1,2,3,4}\b', '', text)
        text = re.sub(r'https?://\S+|www\.\S+', '', text)
        text = re.sub(r'\b\w{26,}\b', '', text)
    return text

# %%
data['Discussion'] = data['Discussion'].apply(lambda x: remove_chars(x) if isinstance(x, str) else x)

# %%
data = data[data['Discussion'].apply(lambda x: len(x) >= 10)] #remove records which are too short and will pollute the model

# %%
def clean_text_digits(text):
    # Tokenize the text into words
    tokens = word_tokenize(text)


    translator = str.maketrans('', '', string.punctuation)
    stripped = [w.translate(translator) for w in tokens]

    # Remove remaining tokens that are not alphabetic (including numbers and symbols)
    words = [word for word in stripped if word.isalpha()and len(word) > 2]

    # Join the list of words into a single string
    return ' '.join(words)

# %%
data['Discussion'] = data['Discussion'].apply(clean_text_digits)
df.head()
# Out:
# <ipython-input-23-f76292ae7eca>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Discussion'] = data['Discussion'].apply(clean_text_digits)
#      subReddit                 Date            Datetime  \
# 0  diabetes_t2  2023-12-05 00:00:00 2023-12-05 23:25:00
# 1  diabetes_t2  2023-12-20 00:00:00 2023-12-20 05:13:00
# 2  diabetes_t2  2023-12-23 00:00:00 2023-12-23 23:16:00
# 3  diabetes_t2  2023-12-23 00:00:00 2023-12-23 02:32:00
# 4  diabetes_t2  2023-12-07 00:00:00 2023-12-07 16:34:00
#
#                                           Title  \
# 0  cheapest way to get a cgm without insurance?
# 1                         libre 3 doesn’t stick
# 2                       frustrated with libre 3
# 3                     libre 3 graphs 3 weeks in
# 4                    confused by gmi on libre 3
#
#                                            Body Text Top Comment  \
# 0  well after being told my insurance would cover...
# 1  i’ve used the libre 3 for 3 months off and on....
# 2  i just got off the phone with customer support...
# 3  the first graph was my first full day with my ...
# 4  i'm finding myself confused by the gmi measure...
#
#   Top Comment Reply 1 Top Comment Reply 2 Top Comment Reply 3  \
# 0
# 1
# 2
# 3
# 4
#
#   Top Comment Reply 4                                         Discussion
# 0                      cheapest way  get  cgm without insurance well ...
# 1                      libre  doesn’ stick ’ used the libre  for  mon...
# 2                      frustrated with libre   just got off the phone...
# 3                      libre  graphs  weeks  the first graph was  fir...
# 4                      confused  gmi  libre   finding myself confused...

# %%
# %pip install spacy
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.11.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.10.14)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in /usr/local/lib/python3.10/dist-packages (from pathy>=0.10.0->spacy) (0.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.11.17)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.4)

# %%
import spacy

#spaCy English model loading
nlp = spacy.load("en_core_web_sm")

# %%
def document_length_splitter(texts, character_threshold=20):

  #parse text using spaCy
  if len(texts) > character_threshold:
        # Parse the text using spaCy to extract sentences
        doc = nlp(texts)
        #Return a list of sentences
        return [sentence.text for sentence in doc.sents]
  else:
        # If the text is not too long, return it as a single-element list
        return [texts]

# %%
df2 = data.copy()

# %%
df2['Discussion'] = df2['Discussion'].apply(document_length_splitter)

# %%
df3 = df2.explode('Discussion')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1347 entries, 0 to 1199
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   subReddit            1347 non-null   object
#  1   Date                 1347 non-null   object
#  2   Datetime             1347 non-null   datetime64[ns]
#  3   Title                1347 non-null   object
#  4   Body Text            1347 non-null   object
#  5   Top Comment          1347 non-null   object
#  6   Top Comment Reply 1  1347 non-null   object
#  7   Top Comment Reply 2  1347 non-null   object
#  8   Top Comment Reply 3  1347 non-null   object
#  9   Top Comment Reply 4  1347 non-null   object
#  10  Discussion           1347 non-null   object
# dtypes: datetime64[ns](1), object(10)
# memory usage: 126.3+ KB

# %%
EDA_DF = df3

# %%
keywords = ['prescription', 'pay', 'walmart', 'walgreens', 'fda', 'restrictions', 'tandem', 'insurance', 'cgm insurance']
pattern = '|'.join(keywords)  #patterns
EDA_DF['Contains_Keywords'] = EDA_DF['Discussion'].str.contains(pattern, case=False)

# %%
#data['Contains_Keywords'] = data['Discussion'].str.contains(pattern, case=False)
#data['Contains_Keywords'] = data['Discussion'].apply(lambda x: "prescription" in x or "pay" in x or "walmart" in x or "walgreens" in x or "fda" in x or "restrictions" in x or "pcp" in x or "tandem" in x )

#count of records containing either "prescription" or "pay"
plt.figure(figsize=(8, 6))
sns.countplot(x='Contains_Keywords', data=EDA_DF)
plt.title('Count of Context Polluting Records')
plt.xlabel('Contains Keywords')
plt.ylabel('Number of Records')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='subReddit', data=EDA_DF)
plt.title('Discussion Records by subReddit')
#plt.xlabel('Contains Keywords')
plt.ylabel('Number of Records')
plt.show()

# %% [markdown]
# # **UMAP for Dimensionality Reduction & HDBSCAN for Clustering of topics**
# Sub-models

# %%
from umap import UMAP
from hdbscan import HDBSCAN

umap_model = UMAP(n_neighbors=3, n_components=3, min_dist=0.02, random_state=42)
hdbscan_model = HDBSCAN(min_cluster_size=30, min_samples=10,
                        prediction_data=True, gen_min_span_tree=True)

# %%
# %pip install bertopic
# Out:
# Collecting bertopic
#   Downloading bertopic-0.16.0-py2.py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.1/154.1 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.23.5)
# Requirement already satisfied: hdbscan>=0.8.29 in /usr/local/lib/python3.10/dist-packages (from bertopic) (0.8.33)
# Requirement already satisfied: umap-learn>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (0.5.5)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.2.2)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (4.66.1)
# Collecting sentence-transformers>=0.4.1 (from bertopic)
#   Downloading sentence_transformers-2.3.1-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.8/132.8 kB 18.2 MB/s eta 0:00:00
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (5.15.0)
# Requirement already satisfied: cython<3,>=0.27 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (0.29.37)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.11.4)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2023.3.post1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (23.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.2.0)
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.35.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.1.0+cu121)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.20.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (9.4.0)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (0.58.1)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (0.5.11)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (4.5.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (0.41.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers>=0.4.1->bertopic) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers>=0.4.1->bertopic) (0.15.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers>=0.4.1->bertopic) (0.4.2)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers>=0.4.1->bertopic) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (2.1.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Installing collected packages: sentence-transformers, bertopic
# Successfully installed bertopic-0.16.0 sentence-transformers-2.3.1

# %%
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
from nltk.corpus import stopwords
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.util import ngrams
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
from tqdm.auto import tqdm

# %%
n = len(df3)

# %%
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# # **Stopwords Removal**

# %%
from nltk.corpus import stopwords
stopwords = list(stopwords.words('english')) + ['prescription','doesn','sensor','sensors','yes','lol','lmao','wtf','abbott','abott','pay','month','medicare', 'cgms', 'fda', 'patients', 'voucher', 'doctor', 'dex', 'authorization', 'cost', 'service','medical','covered','freestyle','company','tempo','glucose','cover','mgdl','reading','lot','wanting','want','hours','months','readings','question','since','day','night','first','last','started','ago','dont','using','use','pump','loss','around','new','phone','put','days','app', 'mmol','mmoll', 'drug','heck','the','http', 'https', 'amp', 'com', 'one', 'www', 'anyone', 'can', 'CVS', 'insurance', 'get', 'like', 'back', 'ive', 'would', 'omnipod', 'pharmacy', 'medtronic', 'to', 'turn','up','out','price', 'cgm','sugar','finger','prick','time','really','else','anybody','wait','blood','also','insulin','know','still','feel','got','thank','thanks','think','numbers','stick','going','check','about','even','too','always','much','be','how','yeah','pocket','yeah yeah','for','months']
vectorizer_model = CountVectorizer(ngram_range=(1, 3), stop_words=stopwords)

# %% [markdown]
# # **Embedding**

# %%
embedding_model = SentenceTransformer('all-MiniLM-L6-v2')
embeds = np.zeros((n, embedding_model.get_sentence_embedding_dimension()))
texts = df3['Discussion'].tolist()
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
#texts

# %%
batch_size=10

# %%
 for i in tqdm(range(0,n,batch_size)):
     i_end = min(i+batch_size,n)
     batch = df3['Discussion'].iloc[i:i_end].tolist()
     batch_embed = embedding_model.encode(batch)
     embeds[i:i_end,:] = batch_embed
# Out:
#   0%|          | 0/135 [00:00<?, ?it/s]

# %% [markdown]
# # **Label Generation using additional Representation Models**
# (LLAMA2)

# %%
from bertopic.representation import KeyBERTInspired, MaximalMarginalRelevance, TextGeneration
from transformers import pipeline

# %%
#%pip install openai

# %%
#import openai

# %%
# KeyBERT
keybert = KeyBERTInspired()

# MMR
mmr = MaximalMarginalRelevance(diversity=0.3)

#Text Generation with google flan
#generator = pipeline('text2text-generation', model='google/flan-t5-base')
#gflan = TextGeneration(generator)

#client = openai.OpenAI(api_key="sk-...")#put api key here
#chat_GPT = OpenAI(client, model="gpt-3.5-turbo", delay_in_seconds=10, chat=True)

# All representation models
representation_model = {
    "KeyBERT": keybert,
    #"Google flan t5": gflan,
    "MMR": mmr,
    #"ChatGPT": chat_GPT
}

# %%
# # Create your representation model
# generator = pipeline('text2text-generation', model='google/flan-t5-base')
# representation_model = TextGeneration(generator)

# %%
#prompt = f"I have a topic represented by the following list of keywords: {keyword}. Considering heavily the context of Diabetic users of Continuous Glucose Monitoring sensors, where these keywords are from Reddit posts about Continuous Glucose Monitoring sensors, which Diabetics use to help them manage their condition; Summarise the specific nuance described by the representation."

# %%
# prompt = """
# I have a topic that contains the following documents:
# [DOCUMENTS]
# The topic is described by the following keywords: [KEYWORDS]

# Based on the information above, extract a short topic label in the following format:
# topic: <topic label>
# """

# %% [markdown]
# # **BERTopic Model**
# ---
# Train, add sub-models, tune hyperparameters below

# %%
BERTopic_model = BERTopic(
    #sub-models:
    umap_model=umap_model,
    hdbscan_model=hdbscan_model,
    embedding_model=embedding_model,
    vectorizer_model=vectorizer_model,
    representation_model=representation_model,
    #hyper-parameters:
    min_topic_size = 50,#careful with tuning this parameter
    top_n_words=15,
    #nr_topics= 8,
    language='english',
    calculate_probabilities=True,
    verbose=True,

)
#model.fit(data['Discussion'])
#topics, probs = model.fit_transform(data['Discussion'])

#Train model:
topics, probs = BERTopic_model.fit_transform(texts, embeddings=embeds)
# Out:
# 2024-02-01 16:44:54,205 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-02-01 16:45:03,521 - BERTopic - Dimensionality - Completed ✓
# 2024-02-01 16:45:03,523 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-02-01 16:45:04,506 - BERTopic - Cluster - Completed ✓
# 2024-02-01 16:45:04,513 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2024-02-01 16:45:19,202 - BERTopic - Representation - Completed ✓

# %%
for i in range(5):
    print(f"{topics[i]}: {df3['Discussion'][i]}")
# Out:
# 1: cheapest way get cgm without insurance well after being told insurance would cover freestyle libre just received letter the mail telling that dont qualify for any cgm because dont take insulin really like figure out actual highs and lows instead random guessing about timing and get better idea exactly how each food hitting and what dawn phenomenon looks like through the night looks like freestyle libre about which means month cant afford that know you can get your first one for free through their website but does anyone know any other ways reduce the cost even can only temporarily maybe can get few months worth data the michigan
# -1: libre doesn stick used the libre for months off and wish had more consistently but never had unit stay more than days been frustrating they never come off because any force accident they just become loose pregnant now and would like able wear cgm for the duration pregnancy what gives please send any advice
# -1: 2    frustrated with libre just got off the phone w...
# 2    finger prick was like beyond frustrated the ou...
# Name: Discussion, dtype: object
# 0: libre graphs weeks the first graph was first full day with libre sensor back dec the second graph today worked hard since being diagnosed nov felt incredibly hopeless when was diagnosed but immediately decided change life around know thing and still got ways but just wanted brag myself bit and more importantly say that diagnosis sometimes second chance turning your health around
# 2: confused gmi libre finding myself confused the gmi measurement libre wear one these all the time last days average glucose yet its telling gmi would when look says the gmi basically your estimated yet according various charts online average glucose going land more around thats prediabetic actually diabetic can someone explain where its getting this number when none the conversion charts match have libre set mgdl for everything underneath the says mmolmol put several measurements per day mysugr well record meals there and several glucose measurements and keep with case out sensor and fingerstick for day two and that day average saying for the record mysugr estimates what the heck libre

# %%
BERTopic_model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="16e1db62-9497-4b56-a10e-9a5203d8e969" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16e1db62-9497-4b56-a10e-9a5203d8e969")) {                    Plotly.newPlot(                        "16e1db62-9497-4b56-a10e-9a5203d8e969",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.007709626892229301,0.008517034920005445,0.008649962548273356,0.018977779952729486,0.021121324806988],"y":["different  ","normal  ","morning  ","libre  ","low  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.008122425714982095,0.008753144766741846,0.009713306974622731,0.013086578556382225,0.02612668369899717],"y":["without  ","tandem  ","need  ","libre  ","dexcom  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.012544048284668778,0.015553763710549097,0.0187940228760033,0.018873557775288253,0.028072477784533457],"y":["data  ","ios  ","scan  ","iphone  ","libre  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.013130797228111722,0.013172429762915046,0.018706964025073332,0.022222616951219756,0.03691841163571442],"y":["libre  ","android  ","alarms  ","alarm  ","signal  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.010771296436898573,0.011177787696020337,0.01371796534502287,0.01591415743466623,0.055254907614192425],"y":["calibrate  ","calibration  ","libre  ","low  ","dexcom  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.019896395845581435,0.020205630015696845,0.022789225891574692,0.023071035075665238,0.0629142196225672],"y":["juggluco  ","android  ","pixel  ","country  ","libre  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.014729956640749765,0.014729956640749765,0.02330161406511412,0.028889675800589848,0.034733940335757364],"y":["skin tac  ","tac  ","adhesive  ","arm  ","skin  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.020390554635086426,0.022050549482842,0.024124760784172673,0.02417708465704685,0.027020171102881987],"y":["send  ","replace  ","faulty  ","call  ","replacement  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0. ...

# %%
BERTopic_model.visualize_hierarchy()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b7f644f3-72bf-4ac8-9c56-2e3474a3c8e9" class="plotly-graph-div" style="height:365px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b7f644f3-72bf-4ac8-9c56-2e3474a3c8e9")) {                    Plotly.newPlot(                        "b7f644f3-72bf-4ac8-9c56-2e3474a3c8e9",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.6688775959948061,0.6688775959948061,0.0],"xaxis":"x","y":[-15.0,-15.0,-25.0,-25.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.6688775959948061,0.7678831200616836,0.7678831200616836,0.0],"xaxis":"x","y":[-20.0,-20.0,-35.0,-35.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.815826085608318,0.815826085608318,0.7678831200616836],"xaxis":"x","y":[-5.0,-5.0,-27.5,-27.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.8595865369605566,0.8595865369605566,0.0],"xaxis":"x","y":[-45.0,-45.0,-55.0,-55.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.6791297862302971,0.6791297862302971,0.0],"xaxis":"x","y":[-65.0,-65.0,-75.0,-75.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.6791297862302971,0.6907051305123192,0.6907051305123192,0.0],"xaxis":"x","y":[-70.0,-70.0,-85.0,-85.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.8595865369605566,0.8868169257633882,0.8868169257633882,0.6907051305123192],"xaxis":"x","y":[-50.0,-50.0,-77.5,-77.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.8281841563228078,0.8281841563228078,0.0],"xaxis":"x","y":[-95.0,-95.0,-105.0,-105.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.8868169257633882,0.9413995210034315,0.9413995210034315,0.8281841563228078],"xaxis":"x","y":[-63.75,-63.75,-100.0,-100.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.815826085608318,1.0433321247905805,1.0433321247905805,0.9413995210034315],"xaxis":"x","y":[-16.25,-16.25,-81.875,-81.875],"yaxis":"y","type":"scatter"}],                        {"autosize":false,"height":365,"hovermode":"closest","showlegend":false,"width":1000,"xaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"ticks":"outside","type":"linear","zeroline":false},"yaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"tickmode":"array","ticks":"outside","ticktext":["9_watch_data_libre","5_libre_country_pixel","2_libre_iphone_scan","3_signal_alarm_alarms","8_transmitter_expired_libre","7_replacement_call_faulty","0_low_libre_morning","4_dexcom_low_libre","1_dexcom_libre_need","6_skin_arm_adhesive","10_compression_arm_lows"],"tickvals":[-5.0,-15.0,-25.0,-35.0,-45.0,-55.0,-65.0,-75.0,-85.0,-95.0,-105.0],"type":"linear","zeroline":false,"range":[-110.0,0.0]},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3 ...

# %%
#run this cell if rows are removed in NLP text cleaning, the index needs to be reset for visualize_documents() function to work
df3.reset_index(drop=True, inplace=True)

# %%
BERTopic_model.visualize_documents(df3['Discussion'], embeddings=embeds)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c9a832ca-3066-40a7-bdda-8aa3de126373" class="plotly-graph-div" style="height:750px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c9a832ca-3066-40a7-bdda-8aa3de126373")) {                    Plotly.newPlot(                        "c9a832ca-3066-40a7-bdda-8aa3de126373",                        [{"hoverinfo":"text","hovertext":["tir and time range fairly new statistic made great strides management cgms made metric possible easy see interpret see people post tir think must experience constant lows probably even severe lows attached screenshot last days looks pretty decent now know call gmi usually within lab drawn the standard deviation key metric calculating wide swings low high the higher deviation wider swing would love see tir correlate different people anyone else post numbers lets see tir gmi avg glucose standard deviation vary thanks dexcom fabulous info","updated ios lost history ios app updated yesterday stopped working white screen downloaded purchase history app store logged back the problem logged back using old account app seems lost historic readings see libreview shows two devices linked account old app new app installed yesterday problem think","put take off great for swimming for bit more security thanks","libre bad initial experience libre repeatedly failing days giving nothing lows ive tried placement arm stomach thighs also severe rashing pustule almost like rejecting piercing within days used use libre seemingly issues curious anyone experienced issues upgrading downgrading back help also pixel afitbit would like readings available glance are options make possible","libre reader app looking app download history libre reader rather using app from tell android app doesnt work well case ive synced sensor reader already solution","confused gmi libre finding myself confused the gmi measurement libre wear one these all the time last days average glucose yet its telling gmi would when look says the gmi basically your estimated yet according various charts online average glucose going land more around thats prediabetic actually diabetic can someone explain where its getting this number when none the conversion charts match have libre set mgdl for everything underneath the says mmolmol put several measurements per day mysugr well record meals there and several glucose measurements and keep with case out sensor and fingerstick for day two and that day average saying for the record mysugr estimates what the heck libre","those you with libre cgm you trust the numbers all went ahead purchased libre sensors out pocket doctor wouldnt prescribe for because she said isnt medically necessary decided was best have some insight into numbers what foods trigger big spikes and progress with the diet and lifestyle changes paid full price with that said feeling like cant trust the numbers for context weighed when diagnosed was was diagnosed jan take metformin twice day started really cutting out the carbs shortly after diagnosis then decided keto and for now because the ada diet guidelines seemed completely crazy have had the first libre sensor applied for basically two full days set target range mgdl mgdl the two days have not seen any spikes above understand there lag between the cgm and blood glucos test however whenever test blood between and for part the day when compensate for lag the cgm seems pretty close sometimes seems way off guess just worried that the progress looks like making illusion really want believe that doing the right things for body know this marathon not sprint but also figure you got train the right way run marathon any you with the libre others you trust the readings","high","yes there are two hooks the side around where stars from rectangula ...

# %%
hdbscan_model.condensed_tree_.plot(select_clusters=True)
# Out:
# <Axes: ylabel='$\\lambda$ value'>

# %%
import plotly.express as px

# %%
assert len(topics) == len(df3)

# %%
df3['Topic'] = topics

# %%
df3.head()
# Out:
#      subReddit                 Date            Datetime  \
# 0  diabetes_t2  2023-12-05 00:00:00 2023-12-05 23:25:00
# 1  diabetes_t2  2023-12-20 00:00:00 2023-12-20 05:13:00
# 2  diabetes_t2  2023-12-23 00:00:00 2023-12-23 23:16:00
# 3  diabetes_t2  2023-12-23 00:00:00 2023-12-23 23:16:00
# 4  diabetes_t2  2023-12-23 00:00:00 2023-12-23 02:32:00
#
#                                           Title  \
# 0  cheapest way to get a cgm without insurance?
# 1                         libre 3 doesn’t stick
# 2                       frustrated with libre 3
# 3                       frustrated with libre 3
# 4                     libre 3 graphs 3 weeks in
#
#                                            Body Text Top Comment  \
# 0  well after being told my insurance would cover...
# 1  i’ve used the libre 3 for 3 months off and on....
# 2  i just got off the phone with customer support...
# 3  i just got off the phone with customer support...
# 4  the first graph was my first full day with my ...
#
#   Top Comment Reply 1 Top Comment Reply 2 Top Comment Reply 3  \
# 0
# 1
# 2
# 3
# 4
#
#   Top Comment Reply 4                                         Discussion  \
# 0                      cheapest way get cgm without insurance well af...
# 1                      libre doesn stick used the libre for months of...
# 2                      frustrated with libre just got off the phone w...
# 3                      finger prick was like beyond frustrated the ou...
# 4                      libre graphs weeks the first graph was first f...
#
#    Contains_Keywords  Topic
# 0               True      1
# 1              False     -1
# 2              False     -1
# 3              False      0
# 4              False      2

# %%
topic_counts = df3['Topic'].value_counts()
#data.drop(['Contains_Keywords'], axis=1)
# Create a count plot
sns.set(style="darkgrid")
plt.figure(figsize=(10, 6))
sns.countplot(y='Topic', data=df3, order = topic_counts.index)

# Labeling the plot
plt.title('Documents by Topic')
plt.xlabel('Number of Documents')
plt.ylabel('Topic Class')

# Show the plot
plt.show()

# %%
topic_distr, _ = BERTopic_model.approximate_distribution(texts)
# Out:
# 100%|██████████| 2/2 [00:00<00:00,  2.48it/s]

# %%
BERTopic_model.visualize_distribution(topic_distr[1])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="cd7e7551-0015-4080-b4f4-3f66d5da774d" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cd7e7551-0015-4080-b4f4-3f66d5da774d")) {                    Plotly.newPlot(                        "cd7e7551-0015-4080-b4f4-3f66d5da774d",                        [{"marker":{"color":"#C8D2D7","line":{"color":"#6E8484","width":1}},"orientation":"h","x":[0.13016643456139115,0.0735645600390673,0.15393470571595078,0.06475345856635951,0.06632454611225064,0.3472437091715466,0.06476620953549138,0.09924637629794253],"y":["\u003cb\u003eTopic 0\u003c\u002fb\u003e: low_libre_morning_normal...","\u003cb\u003eTopic 1\u003c\u002fb\u003e: dexcom_libre_need_tandem...","\u003cb\u003eTopic 2\u003c\u002fb\u003e: libre_iphone_scan_ios_da...","\u003cb\u003eTopic 3\u003c\u002fb\u003e: signal_alarm_alarms_andr...","\u003cb\u003eTopic 4\u003c\u002fb\u003e: dexcom_low_libre_calibra...","\u003cb\u003eTopic 5\u003c\u002fb\u003e: libre_country_pixel_andr...","\u003cb\u003eTopic 8\u003c\u002fb\u003e: transmitter_expired_libr...","\u003cb\u003eTopic 9\u003c\u002fb\u003e: watch_data_libre_libreli..."],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewid ...

# %%
probs
# Out:
# array([[1.23371941e-308, 1.00000000e+000, 8.93413267e-309, ...,
#         8.94060272e-309, 7.61572286e-309, 7.08448220e-309],
#        [1.98771214e-001, 2.87244072e-002, 3.51398034e-002, ...,
#         9.25024597e-002, 2.62357405e-002, 3.25436790e-002],
#        [1.67857002e-001, 2.56747874e-002, 3.01852369e-002, ...,
#         8.82590379e-002, 2.25576327e-002, 2.98568475e-002],
#        ...,
#        [3.74447987e-002, 3.43496126e-002, 2.32993333e-002, ...,
#         6.84603898e-002, 1.85523966e-002, 3.43648715e-001],
#        [5.50449371e-002, 5.98699536e-002, 3.15289813e-002, ...,
#         9.88964721e-002, 2.60767317e-002, 1.66451849e-001],
#        [1.12294115e-308, 1.10714100e-308, 7.71420450e-309, ...,
#         1.90607440e-308, 5.66615163e-309, 3.43974356e-308]])

# %%
topic_distr, topic_token_distr = BERTopic_model.approximate_distribution(texts, calculate_tokens=True)
topic_dist_df = BERTopic_model.visualize_approximate_distribution(texts[1], topic_token_distr[1])
# Out:
# 100%|██████████| 2/2 [00:02<00:00,  1.02s/it]

# %%
topic_dist_df
# Out:
# <style type="text/css">
# #T_7b609_row0_col0, #T_7b609_row0_col1, #T_7b609_row0_col2, #T_7b609_row0_col3, #T_7b609_row0_col9, #T_7b609_row0_col10, #T_7b609_row0_col11, #T_7b609_row0_col12, #T_7b609_row0_col13, #T_7b609_row0_col14, #T_7b609_row0_col15, #T_7b609_row0_col16, #T_7b609_row0_col17, #T_7b609_row0_col18, #T_7b609_row0_col19, #T_7b609_row0_col20, #T_7b609_row0_col21, #T_7b609_row0_col22, #T_7b609_row0_col23, #T_7b609_row0_col24, #T_7b609_row0_col25, #T_7b609_row0_col26, #T_7b609_row0_col27, #T_7b609_row0_col28, #T_7b609_row0_col29, #T_7b609_row0_col30, #T_7b609_row0_col31, #T_7b609_row0_col32, #T_7b609_row0_col33, #T_7b609_row0_col34, #T_7b609_row0_col35, #T_7b609_row0_col36, #T_7b609_row0_col37, #T_7b609_row0_col38, #T_7b609_row0_col39, #T_7b609_row0_col40, #T_7b609_row0_col41, #T_7b609_row0_col42, #T_7b609_row0_col43, #T_7b609_row0_col44, #T_7b609_row0_col45, #T_7b609_row0_col46, #T_7b609_row0_col47, #T_7b609_row0_col48, #T_7b609_row0_col49, #T_7b609_row0_col50, #T_7b609_row0_col51, #T_7b609_row0_col52, #T_7b609_row0_col53, #T_7b609_row1_col0, #T_7b609_row1_col1, #T_7b609_row1_col2, #T_7b609_row1_col3, #T_7b609_row1_col9, #T_7b609_row1_col10, #T_7b609_row1_col11, #T_7b609_row1_col12, #T_7b609_row1_col13, #T_7b609_row1_col14, #T_7b609_row1_col15, #T_7b609_row1_col16, #T_7b609_row1_col17, #T_7b609_row1_col18, #T_7b609_row1_col19, #T_7b609_row1_col20, #T_7b609_row1_col21, #T_7b609_row1_col22, #T_7b609_row1_col23, #T_7b609_row1_col24, #T_7b609_row1_col25, #T_7b609_row1_col26, #T_7b609_row1_col27, #T_7b609_row1_col28, #T_7b609_row1_col29, #T_7b609_row1_col30, #T_7b609_row1_col31, #T_7b609_row1_col32, #T_7b609_row1_col33, #T_7b609_row1_col34, #T_7b609_row1_col35, #T_7b609_row1_col36, #T_7b609_row1_col37, #T_7b609_row1_col38, #T_7b609_row1_col39, #T_7b609_row1_col40, #T_7b609_row1_col41, #T_7b609_row1_col42, #T_7b609_row1_col43, #T_7b609_row1_col44, #T_7b609_row1_col45, #T_7b609_row1_col46, #T_7b609_row1_col47, #T_7b609_row1_col48, #T_7b609_row1_col49, #T_7b609_row1_col50, #T_7b609_row1_col51, #T_7b609_row1_col52, #T_7b609_row1_col53, #T_7b609_row2_col0, #T_7b609_row2_col1, #T_7b609_row2_col2, #T_7b609_row2_col3, #T_7b609_row2_col9, #T_7b609_row2_col10, #T_7b609_row2_col11, #T_7b609_row2_col12, #T_7b609_row2_col13, #T_7b609_row2_col14, #T_7b609_row2_col15, #T_7b609_row2_col16, #T_7b609_row2_col17, #T_7b609_row2_col18, #T_7b609_row2_col19, #T_7b609_row2_col20, #T_7b609_row2_col21, #T_7b609_row2_col22, #T_7b609_row2_col23, #T_7b609_row2_col24, #T_7b609_row2_col25, #T_7b609_row2_col26, #T_7b609_row2_col27, #T_7b609_row2_col28, #T_7b609_row2_col29, #T_7b609_row2_col30, #T_7b609_row2_col31, #T_7b609_row2_col32, #T_7b609_row2_col33, #T_7b609_row2_col34, #T_7b609_row2_col35, #T_7b609_row2_col36, #T_7b609_row2_col37, #T_7b609_row2_col38, #T_7b609_row2_col39, #T_7b609_row2_col40, #T_7b609_row2_col41, #T_7b609_row2_col42, #T_7b609_row2_col43, #T_7b609_row2_col44, #T_7b609_row2_col45, #T_7b609_row2_col46, #T_7b609_row2_col47, #T_7b609_row2_col48, #T_7b609_row2_col49, #T_7b609_row2_col50, #T_7b609_row2_col51, #T_7b609_row2_col52, #T_7b609_row2_col53, #T_7b609_row3_col0, #T_7b609_row3_col1, #T_7b609_row3_col2, #T_7b609_row3_col3, #T_7b609_row3_col9, #T_7b609_row3_col10, #T_7b609_row3_col11, #T_7b609_row3_col12, #T_7b609_row3_col13, #T_7b609_row3_col14, #T_7b609_row3_col15, #T_7b609_row3_col16, #T_7b609_row3_col17, #T_7b609_row3_col18, #T_7b609_row3_col19, #T_7b609_row3_col20, #T_7b609_row3_col21, #T_7b609_row3_col22, #T_7b609_row3_col23, #T_7b609_row3_col24, #T_7b609_row3_col25, #T_7b609_row3_col26, #T_7b609_row3_col27, #T_7b609_row3_col28, #T_7b609_row3_col29, #T_7b609_row3_col30, #T_7b609_row3_col31, #T_7b609_row3_col32, #T_7b609_row3_col33, #T_7b609_row3_col34, #T_7b609_row3_col35, #T_7b609_row3_col36, #T_7b609_row3_col37, #T_7b609_row3_col38, #T_7b609_row3_col39, #T_7b609_row3_col40, #T_7b609_row3_col41, #T_7b609_row3_col42, #T_7b609_row3_col43, #T_7b609_row3_col44, #T_7b609_row3_col45, #T_7b609_row3_col46, #T_7b609_row3_col47, #T_7b609_row3_col48, #T_7b609_ ...

# %% [markdown]
# # **BERTopic Model Output Evaluation**

# %% [markdown]
# # **Coherence**
# Measures the degree of semantic similarity between high scoring words in the topic. These measures help distinguish between topics that are semantically interpretable and topics that are artifacts of statistical inference.
#
# C_V Measure: A coherence measure that uses a sliding window, a one-set segmentation of the top words and an indirect confirmation measure that uses normalized pointwise mutual information (NPMI) and the cosine similarity.

# %%
coherence = BERTopic_model.get_topic_info(); coherence.head(10)
# Out:
#    Topic  Count                                Name  \
# 0     -1    316                -1_libre_arm_low_bad
# 1      0    205          0_low_libre_morning_normal
# 2      1    153          1_dexcom_libre_need_tandem
# 3      2    140             2_libre_iphone_scan_ios
# 4      3     95       3_signal_alarm_alarms_android
# 5      4     93      4_dexcom_low_libre_calibration
# 6      5     75       5_libre_country_pixel_android
# 7      6     75             6_skin_arm_adhesive_tac
# 8      7     57   7_replacement_call_faulty_replace
# 9      8     52  8_transmitter_expired_libre_signal
#
#                                       Representation  \
# 0  [libre, arm, low, bad, dexcom, issues, alarm, ...
# 1  [low, libre, morning, normal, different, test,...
# 2  [dexcom, libre, need, tandem, without, people,...
# 3  [libre, iphone, scan, ios, data, working, upda...
# 4  [signal, alarm, alarms, android, libre, settin...
# 5  [dexcom, low, libre, calibration, calibrate, g...
# 6  [libre, country, pixel, android, juggluco, upd...
# 7  [skin, arm, adhesive, tac, skin tac, placement...
# 8  [replacement, call, faulty, replace, send, ope...
# 9  [transmitter, expired, libre, signal, expires,...
#
#                                              KeyBERT  \
# 0  [alarms, alarm, alerts, ios, alert, device, de...
# 1  [diabetes, diabetic, sugars, diagnosed, meter,...
# 2  [dexcom, libre dexcom, diabetes, appointment, ...
# 3  [libre iphone, apps, libreview, android, ios, ...
# 4  [alarms, signal alarm, alarm, alerts, apps, al...
# 5  [dexcom libre, dexcom, dexcoms, used dexcom, c...
# 6  [libre android, devices libre, libre libre, li...
# 7  [skin tac, skin grip, skin, tac, arm, tips, gr...
# 8  [defective, faulty, replacements, patches, sen...
# 9  [expired transmitter, transmitter dead, signal...
#
#                                                  MMR  \
# 0  [libre, arm, low, dexcom, issues, alarm, updat...
# 1  [low, libre, morning, normal, different, test,...
# 2  [dexcom, libre, need, tandem, without, take, a...
# 3  [libre, scan, ios, data, error, librelink, blu...
# 4  [signal, alarm, alarms, android, libre, settin...
# 5  [dexcom, low, libre, calibration, calibrate, i...
# 6  [libre, country, pixel, android, juggluco, upd...
# 7  [skin, arm, adhesive, skin tac, placement, tap...
# 8  [call, faulty, replace, send, open, bad, issue...
# 9  [transmitter, expired, libre, signal, expires,...
#
#                                  Representative_Docs
# 0  [medtronic should embarrassed dexcom tldr the ...
# 1  [consistently very inaccurate cgm readings hig...
# 2  [yup saw comment recently similar post that sa...
# 3  [experience with the libre far put first senso...
# 4  [just have say the alarm mgdl ridiculous the p...
# 5  [new dexcom sensor issues just started using d...
# 6  [its because libre designed used with only one...
# 7  [advice sensor positioning everyone hope day g...
# 8  [call abbott get replacement thats your option...
# 9  [libre sensor issue observation ive been havin...

# %%
coherence_df = coherence

# %%
coherence_df
# Out:
#     Topic  Count                                      Name  \
# 0      -1    316                      -1_libre_arm_low_bad
# 1       0    205                0_low_libre_morning_normal
# 2       1    153                1_dexcom_libre_need_tandem
# 3       2    140                   2_libre_iphone_scan_ios
# 4       3     95             3_signal_alarm_alarms_android
# 5       4     93            4_dexcom_low_libre_calibration
# 6       5     75             5_libre_country_pixel_android
# 7       6     75                   6_skin_arm_adhesive_tac
# 8       7     57         7_replacement_call_faulty_replace
# 9       8     52        8_transmitter_expired_libre_signal
# 10      9     49            9_watch_data_libre_librelinkup
# 11     10     37  10_compression_arm_lows_compression lows
#
#                                        Representation  \
# 0   [libre, arm, low, bad, dexcom, issues, alarm, ...
# 1   [low, libre, morning, normal, different, test,...
# 2   [dexcom, libre, need, tandem, without, people,...
# 3   [libre, iphone, scan, ios, data, working, upda...
# 4   [signal, alarm, alarms, android, libre, settin...
# 5   [dexcom, low, libre, calibration, calibrate, g...
# 6   [libre, country, pixel, android, juggluco, upd...
# 7   [skin, arm, adhesive, tac, skin tac, placement...
# 8   [replacement, call, faulty, replace, send, ope...
# 9   [transmitter, expired, libre, signal, expires,...
# 10  [watch, data, libre, librelinkup, watches, app...
# 11  [compression, arm, lows, compression lows, sle...
#
#                                               KeyBERT  \
# 0   [alarms, alarm, alerts, ios, alert, device, de...
# 1   [diabetes, diabetic, sugars, diagnosed, meter,...
# 2   [dexcom, libre dexcom, diabetes, appointment, ...
# 3   [libre iphone, apps, libreview, android, ios, ...
# 4   [alarms, signal alarm, alarm, alerts, apps, al...
# 5   [dexcom libre, dexcom, dexcoms, used dexcom, c...
# 6   [libre android, devices libre, libre libre, li...
# 7   [skin tac, skin grip, skin, tac, arm, tips, gr...
# 8   [defective, faulty, replacements, patches, sen...
# 9   [expired transmitter, transmitter dead, signal...
# 10  [smart watches, dexcom apple watch, smartwatch...
# 11  [sleep compression lows, gotten compression lo...
#
#                                                   MMR  \
# 0   [libre, arm, low, dexcom, issues, alarm, updat...
# 1   [low, libre, morning, normal, different, test,...
# 2   [dexcom, libre, need, tandem, without, take, a...
# 3   [libre, scan, ios, data, error, librelink, blu...
# 4   [signal, alarm, alarms, android, libre, settin...
# 5   [dexcom, low, libre, calibration, calibrate, i...
# 6   [libre, country, pixel, android, juggluco, upd...
# 7   [skin, arm, adhesive, skin tac, placement, tap...
# 8   [call, faulty, replace, send, open, bad, issue...
# 9   [transmitter, expired, libre, signal, expires,...
# 10  [data, libre, librelinkup, watches, apple watc...
# 11  [arm, lows, compression lows, sleep, arms, wak...
#
#                                   Representative_Docs
# 0   [medtronic should embarrassed dexcom tldr the ...
# 1   [consistently very inaccurate cgm readings hig...
# 2   [yup saw comment recently similar post that sa...
# 3   [experience with the libre far put first senso...
# 4   [just have say the alarm mgdl ridiculous the p...
# 5   [new dexcom sensor issues just started using d...
# 6   [its because libre designed used with only one...
# 7   [advice sensor positioning everyone hope day g...
# 8   [call abbott get replacement thats your option...
# 9   [libre sensor issue observation ive been havin...
# 10  [libre data garmin watches hey yall using libr...
# 11  [you sleeping your side and that the side wher...

# %%
df3.to_excel('/content/drive/MyDrive/Colab Notebooks/BERTopic Model Outputs.xlsx')

# %%
coherence_df.to_excel('/content/drive/MyDrive/Colab Notebooks/BERTopic Coherence.xlsx')

# %% [markdown]
# # **Feed the Labelled Embedded Dataset to Classifiers**

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.svm import LinearSVC, SVC
from sklearn.metrics import f1_score, recall_score
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression

# %%
 classifier_dataset = list(zip(embeds,topics))

# %%
 X_train, X_test, y_train, y_test = train_test_split(
     [embed[0] for embed in classifier_dataset],  # features (embeddings)
     [embed[1] for embed in classifier_dataset],  # labels (topics)
     test_size=0.2, random_state=42
 )

# %%
nb_model = MultinomialNB()
nb_model.fit(X_train,y_train)

predictions_nb = nb_model.predict(X_test)

#print("Multinomial NB Accuracy Score = ",accuracy_score(predictions_nb, Test_Y)*100)

f1 = f1_score(y_test, predictions_nb, average='weighted')  # Use 'macro' or 'micro' if needed
recall = recall_score(y_test, predictions_nb, average='weighted')  # Use 'macro' or 'micro' if needed
print("Multinomial NB Accuracy Score = ",accuracy_score(predictions_nb, y_test)*100)
print(f"Multinomial NB F1 Score = {f1 * 100}")
print(f"Multinomial NB Recall = {recall * 100}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-0f8fd578e5e9> in <cell line: 2>()
#       1 nb_model = MultinomialNB()
# ----> 2 nb_model.fit(X_train,y_train)
#       3
#       4 predictions_nb = nb_model.predict(X_test)
#       5
#
# /usr/local/lib/python3.10/dist-packages/sklearn/naive_bayes.py in fit(self, X, y, sample_weight)
#     774         n_classes = Y.shape[1]
#     775         self._init_counters(n_classes, n_features)
# --> 776         self._count(X, Y)
#     777         alpha = self._check_alpha()
#     778         self._update_feature_log_prob(alpha)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/naive_bayes.py in _count(self, X, Y)
#     896     def _count(self, X, Y):
#     897         """Count and smooth feature occurrences."""
# --> 898         check_non_negative(X, "MultinomialNB (input X)")
#     899         self.feature_count_ += safe_sparse_dot(Y.T, X)
#     900         self.class_count_ += Y.sum(axis=0)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_non_negative(X, whom)
#    1416
#    1417     if X_min < 0:
# -> 1418         raise ValueError("Negative values in data passed to %s" % whom)
#    1419
#    1420
#
# ValueError: Negative values in data passed to MultinomialNB (input X)

# %%
svm_model = SVC(C=1.0, kernel='linear', degree=3, gamma='auto', class_weight = 'balanced', probability=True)
svm_model.fit(X_train,y_train)

predictions_svm = svm_model.predict(X_test)
f1 = f1_score(y_test, predictions_svm, average='weighted')  # Use 'macro' or 'micro' if needed
recall = recall_score(y_test, predictions_svm, average='weighted')  # Use 'macro' or 'micro' if needed
print("Nonlinear SVM Accuracy Score = ",accuracy_score(predictions_svm, y_test)*100)
print(f"Nonlinear SVM F1 Score = {f1 * 100}")
print(f"Nonlinear SVM Recall = {recall * 100}")
print(classification_report(y_test, predictions_svm))
# Out:
# Nonlinear SVM Accuracy Score =  68.14814814814815
# Nonlinear SVM F1 Score = 66.40075542000916
# Nonlinear SVM Recall = 68.14814814814815
#               precision    recall  f1-score   support
#
#           -1       0.71      0.32      0.44        62
#            0       0.69      0.83      0.75        35
#            1       0.69      0.69      0.69        36
#            2       0.62      0.82      0.71        28
#            3       0.74      1.00      0.85        14
#            4       0.68      0.62      0.65        24
#            5       0.87      0.76      0.81        17
#            6       0.75      0.86      0.80        14
#            7       0.75      0.69      0.72        13
#            8       0.47      0.88      0.61         8
#            9       0.56      1.00      0.71        10
#           10       0.70      0.78      0.74         9
#
#     accuracy                           0.68       270
#    macro avg       0.69      0.77      0.71       270
# weighted avg       0.70      0.68      0.66       270

# %%
log_reg_model = LogisticRegression(max_iter=1000, class_weight='balanced')
log_reg_model.fit(X_train, y_train)
predictions_log_reg = log_reg_model.predict(X_test)

print(classification_report(y_test, predictions_log_reg))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.72      0.21      0.33        62
#            0       0.70      0.86      0.77        35
#            1       0.73      0.61      0.67        36
#            2       0.59      0.68      0.63        28
#            3       0.65      0.93      0.76        14
#            4       0.59      0.54      0.57        24
#            5       0.64      0.82      0.72        17
#            6       0.65      0.93      0.76        14
#            7       0.44      0.54      0.48        13
#            8       0.33      0.88      0.48         8
#            9       0.59      1.00      0.74        10
#           10       0.67      0.67      0.67         9
#
#     accuracy                           0.62       270
#    macro avg       0.61      0.72      0.63       270
# weighted avg       0.65      0.62      0.59       270

# %%
cm_svm = confusion_matrix(y_test, predictions_svm)
sns.heatmap(cm_svm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
cm_logreg = confusion_matrix(y_test, predictions_log_reg)
sns.heatmap(cm_logreg, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
gbm_model = GradientBoostingClassifier(random_state=42)
gbm_model.fit(X_train, y_train)
gbm_predictions = gbm_model.predict(X_test)

print(classification_report(y_test, gbm_predictions))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.34      0.71      0.46        62
#            0       0.68      0.66      0.67        35
#            1       0.72      0.36      0.48        36
#            2       0.75      0.54      0.63        28
#            3       0.69      0.64      0.67        14
#            4       0.67      0.50      0.57        24
#            5       0.91      0.59      0.71        17
#            6       0.86      0.43      0.57        14
#            7       0.38      0.23      0.29        13
#            8       0.50      0.25      0.33         8
#            9       0.71      0.50      0.59        10
#           10       1.00      0.22      0.36         9
#
#     accuracy                           0.53       270
#    macro avg       0.68      0.47      0.53       270
# weighted avg       0.63      0.53      0.54       270

# %%
cm_gbm = confusion_matrix(y_test, gbm_predictions)
sns.heatmap(cm_gbm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
